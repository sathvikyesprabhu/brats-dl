# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("./train_labels/train_gt_4_13.png")
plt.imshow(img)
plt.show()
histr=cv2.calcHist([img],[0],None,[256],[,256])
plt.plot(histr)
plt.show()

# %%
# New weights: [8 4 6 1]
